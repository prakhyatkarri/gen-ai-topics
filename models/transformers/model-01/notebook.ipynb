# %%
from huggingface_hub import notebook_login

notebook_login(skip_if_logged_in=True)

# %%
# remove ! if installing from the CLI
# !pip install torch

# %%
# remove ! if installing from the CLI
# !pip install -U transformers datasets evaluate accelerate timm

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
# from transformers import AutoModelForMultimodalLM, AutoTokenizer

model_name = "meta-llama/Llama-2-7b-hf"

model = AutoModelForCausalLM.from_pretrained(model_name)
#  model_name, dtype="auto", device="auto")
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2262, in _LazyModule.__getattr__(self, name)
#    2261 try:
# -> 2262     module = self._get_module(self._class_to_module[name])
#    2263     value = getattr(module, name)
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2496, in _LazyModule._get_module(self, module_name)
#    2495 except Exception as e:
# -> 2496     raise e
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2494, in _LazyModule._get_module(self, module_name)
#    2493 try:
# -> 2494     return importlib.import_module("." + module_name, self.__name__)
#    2495 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1152, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:705, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\generation\utils.py:44
#      43 from ..integrations.fsdp import is_fsdp_managed_module
# ---> 44 from ..masking_utils import create_masks_for_generate
#      45 from ..tokenization_python import ExtensionsTrie
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\masking_utils.py:38
#      37 if _is_torch_greater_or_equal_than_2_6:
# ---> 38     from torch._dynamo._trace_wrapped_higher_order_op import TransformGetItemToIndex
#      41 logger = logging.get_logger(__name__)
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\torch\_dynamo\__init__.py:13
#      11 import torch
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\torch\_dynamo\convert_frame.py:53
#      52 from torch._dynamo.distributed import get_compile_pg
# ---> 53 from torch._dynamo.symbolic_convert import TensorifyState
#      54 from torch._guards import compile_context, CompileContext, CompileId, tracing
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\torch\_dynamo\symbolic_convert.py:58
#      56 from torch.utils._functools import cache_method
# ---> 58 from . import (
#      59     config,
#      60     exc,
#      61     graph_break_hints,
#      62     logging as torchdynamo_logging,
#      63     trace_rules,
#      64     variables,
#      65 )
#      66 from .bytecode_analysis import (
#      67     get_indexof,
#      68     JUMP_OPNAMES,
#      69     livevars_analysis,
#      70     propagate_line_nums,
#      71 )
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\torch\_dynamo\trace_rules.py:47
#      46 import torch
# ---> 47 import torch._inductor.test_operators
#      48 import torch.distributed
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\torch\_inductor\__init__.py:9
#       7 from typing import Any, IO, Literal, Optional, TYPE_CHECKING, Union
# ----> 9 import torch._inductor.config
#      10 import torch.fx
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\torch\_inductor\config.py:261
#     256 # register custom graph optimization pass hook. so far, pre/post passes are
#     257 # only applied before/after pattern_matcher in post_grad_passes.
#     258 #
#     259 # Implement CustomGraphPass to allow Inductor to graph compiled artifacts
#     260 # to which your custom passes have been applied:
# --> 261 post_grad_custom_pre_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#     262 post_grad_custom_post_pass: torch._inductor.custom_graph_pass.CustomGraphPassType = None
#
# AttributeError: partially initialized module 'torch._inductor' has no attribute 'custom_graph_pass' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2262, in _LazyModule.__getattr__(self, name)
#    2261 try:
# -> 2262     module = self._get_module(self._class_to_module[name])
#    2263     value = getattr(module, name)
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2496, in _LazyModule._get_module(self, module_name)
#    2495 except Exception as e:
# -> 2496     raise e
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2494, in _LazyModule._get_module(self, module_name)
#    2493 try:
# -> 2494     return importlib.import_module("." + module_name, self.__name__)
#    2495 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1152, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:705, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in _LoaderBasics.exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\models\auto\modeling_auto.py:21
#      20 from ...utils import logging
# ---> 21 from .auto_factory import (
#      22     _BaseAutoBackboneClass,
#      23     _BaseAutoModelClass,
#      24     _LazyAutoMapping,
#      25     auto_class_update,
#      26 )
#      27 from .configuration_auto import CONFIG_MAPPING_NAMES
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\models\auto\auto_factory.py:42
#      41 if is_torch_available():
# ---> 42     from ...generation import GenerationMixin
#      45 logger = logging.get_logger(__name__)
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2350, in _LazyModule.__getattr__(self, name)
#    2349         else:
# -> 2350             raise ModuleNotFoundError(
#    2351                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2352             ) from e
#    2354 elif name in self._modules:
#
# ModuleNotFoundError: Could not import module 'GenerationMixin'. Are this object's requirements defined correctly?
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 2
#       1 # from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 2 from transformers import AutoModelForMultimodalLM, AutoTokenizer
#       3
#       4 model_name = "meta-llama/Llama-2-7b-hf"
#       5
#
# File k:\Learning\Git\gen-ai-topics\.env\Lib\site-packages\transformers\utils\import_utils.py:2350, in _LazyModule.__getattr__(self, name)
#    2346                     raise ModuleNotFoundError(
#    2347                         f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2348                     ) from e
#    2349         else:
# -> 2350             raise ModuleNotFoundError(
#    2351                 f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2352             ) from e
#    2354 elif name in self._modules:
#    2355     try:
#
# ModuleNotFoundError: Could not import module 'AutoModelForMultimodalLM'. Are this object's requirements defined correctly?

# %%
# !pip uninstall torch

# %%
# !pip uninstall transformers datasets evaluate accelerate timm
